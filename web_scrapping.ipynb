# %% [markdown]
# # Scrapping marathon results
# #### Seungmin Lee
# ---
# ## Objective
# ---
# Our goal for this project is to retrieve data from the [2019 Chicago Marathon](https://results.chicagomarathon.com/well-known/2019/) and create a dataframe showing the top 50 male runners.
#
# For that purpose we will be using the follow tools:
# - `requests`: Allows us to retrieve data from a website.
# - `BeautifulSoup`: Aides in sorting html information.
# - `pandas`: Will be used in creating a data frame containing top 50 male runners.
# - `time`: Adds a delay for get requests to prevent potential issues.

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import time

# %%
# Specific parameters to obtain top 50 male contenders
params = {"event":"MAR", "search[sex]":"M", "search[age_class]":"%", "num_results":"50"}
marathonURL = requests.get("https://results.chicagomarathon.com/well-known/2019/?pid=list", params = params).text
soup = BS(marathonURL)
#print(soup.prettify())

# %% [markdown]
# Since we will be pulling information for all 50 male runners, we need to know what type of information we will be working with. To start, we will be accessing the first place male runner, Cherono, Lawrence.

# %%
# URL linking to Lawrence's profile
test1 = requests.get("https://results.chicagomarathon.com/well-known/2019/?content=detail&fpid=list&pid=list&idp=999999107FA317000023A4AD&lang=EN_CAP&event=MAR&lang=EN_CAP&num_results=50&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search_event=MAR").text
soup1 = BS(test1)
# Most of the data we will be working with is under the "td" tag
tdTag = soup1.find_all("td")
#tdTag

# %% [markdown]
# The information that we want are the following:
# - Name: `<td class="f-__fullname last">`
# - Age Group: `<td class="f-age_class last">`
# - bib Number: `<td class="f-start_no_text last">`
# - Age: `<td class="f-age last">`
# - City/State: `<td class="f-__city_state last">`
# - Split Times: `<td class="time">`
#
# The first 5 can be obtained by slicing for the first 5 instances of "td".
#
# For Split Times, they'll be divided to the following:
# - 05K: Element 13
# - 10K: Element 21
# - 15K: Element 27
# - 20K: Element 34
# - HALF: Element 41
# - 25K: Element 48
# - 30K: Element 55
# - 35K: Element 62
# - 40K: Element 69
# - Finish: Element 76

# %%
# Obtains name, age group, bib number, age, city/state
first5 = [x.get_text() for x in tdTag[0:5]]
first5
# Out:
# ['Marathon', '2019', 'Cherono, Lawrence (KEN)', '30-34', '4']

# %%
# Obtains split times
times = [x.get_text() for x in tdTag[13:77:7]]
times
# Out:
# ['14:45',
#  '14:43',
#  '14:43',
#  '14:50',
#  '03:14',
#  '11:42',
#  '15:02',
#  '14:55',
#  '15:16',
#  '06:35']

# %%
# Brings the 2 together into 1 list containing everything we want
info = first5 + times
info
# Out:
# ['Marathon',
#  '2019',
#  'Cherono, Lawrence (KEN)',
#  '30-34',
#  '4',
#  '14:45',
#  '14:43',
#  '14:43',
#  '14:50',
#  '03:14',
#  '11:42',
#  '15:02',
#  '14:55',
#  '15:16',
#  '06:35']

# %%
h4tags = soup.find_all("h4") # Each runner's information/profile links are separated by the common "h4" tag
marathonList = []
for h4 in h4tags:
    profileURL = "https://results.chicagomarathon.com/2019/" + h4.find('a')['href'] 
    temp = requests.get(profileURL) # Pulling runner's profile
    tempSoup = BS(temp.text)
    tdTag = tempSoup.find_all("td")
    tempList = [x.get_text() for x in tdTag[0:5]] + [x.get_text() for x in tdTag[13:77:7]]
    marathonList.append(tempList) # Appends a list containing a runner's information from their profile
    time.sleep(2) # Ensures that there is a delay between each get request
#print(marathonList)

# %%
# "col" contains the header for the data frame
col = ["Name (CTZ)","Age Group","Bib Number","Age","City,State","05K","10K","15K","20K","HALF","25K","30K","35K","40K","Finish"]
df = pd.DataFrame(marathonList, columns = col)
df
# Out:
#               Name (CTZ) Age Group                    Bib Number    Age  \
# 0   Exhibition Handcycle      2019       Robinson, Anthony (USA)      –
# 1               Marathon      2019       Cherono, Lawrence (KEN)  30-34
# 2             Wheelchair      2019       Romanchuk, Daniel (USA)   MT53
# 3   Exhibition Handcycle      2019            Walton, Jess (USA)      –
# 4               Marathon      2019          Debela, Dejene (ETH)  20-24
# 5             Wheelchair      2019             Weir, David (GBR)   MT53
# 6   Exhibition Handcycle      2019            Morgan, Carl (USA)      –
# 7               Marathon      2019          Mengstu, Asefa (ETH)  30-34
# 8             Wheelchair      2019          Van Dyk, Ernst (RSA)   MT53
# 9   Exhibition Handcycle      2019              Sapp, Greg (USA)      –
# 10              Marathon      2019           Karoki, Bedan (KEN)  25-29
# 11            Wheelchair      2019          Smith, Johnboy (GBR)   MT53
# 12  Exhibition Handcycle      2019          Johnson, James (USA)      –
# 13              Marathon      2019            Abdi, Bashir (BEL)  30-34
# 14            Wheelchair      2019           Watanabe, Sho (JPN)   MT53
# 15  Exhibition Handcycle      2019      Koulchar, Nicholas (USA)      –
# 16              Marathon      2019             Tura, Seifu (ETH)  20-24
# 17            Wheelchair      2019             Pike, Aaron (USA)   MT53
# 18  Exhibition Handcycle      2019        Alvarez, William (USA)      –
# 19              Marathon      2019         Chumba, Dickson (KEN)  30-34
# 20            Wheelchair      2019           Madera, Jorge (ESP)   MT53
# 21  Exhibition Handcycle      2019          Simmons, Teddy (USA)      –
# 22              Marathon      2019               Farah, Mo (GBR)  35-39
# 23            Wheelchair      2019          Hokinoue, Kota (JPN)   MT53
# 24  Exhibition Handcycle      2019       Sanchez, Salvador (USA)      –
# 25              Marathon      2019            Riley, Jacob (USA)  30-34
# 26            Wheelchair      2019         Nishida, Hiroki (JPN)   MT53
# 27              Marathon      2019           Mock, Jerrell (USA)  20-24
# 28            Wheelchair      2019          Yoshida, Ryota (JPN)   MT53
# 29              Marathon      2019         Stinson, Parker (USA)  25-29
# 30            Wheelchair      2019  Valladares, Juan Ramon (CRC)   MT53
# 31              Marathon      2019      Bumbalough, Andrew (USA)  30-34
# 32            Wheelchair      2019        Monahan, Patrick (IRL)   MT53
# 33              Marathon      2019           Oishi, Minato (JPN)  30-34
# 34            Wheelchair      2019           Lawson, Simon (GBR)   MT53
# 35              Marathon      2019       Mcdonald, Matthew (USA)  25-29
# 36            Wheelchair      2019       Zaragoza, Alfonso (MEX)   MT53
# 37              Marathon      2019            Smith, Scott (USA)  20-24
# 38            Wheelchair      2019         Botello, Rafael (ESP)   MT53
# 39              Marathon      2019          Gregg, Brendan (USA)  30-34
# 40            Wheelchair      2019            George, Josh (USA)   MT53
# 41              Marathon      2019            Droddy, Noah (USA)  25-29
# 42            Wheelchair      2019          Senbeta, James (USA)   MT53
# 43              Marathon      2019        Given, Wilkerson (USA)  25-29
# 44            Wheelchair      2019          Siemann, Brian (USA)   MT53
# 45              Marathon      2019          Estrada, Diego (USA)  25-29
# 46            Wheelchair      2019     Clemmons, Christian (USA)   MT53
# 47              Marathon      2019       Hayakawa, Tsubasa (JPN)  25-29
# 48            Wheelchair      2019          Aguilar, Fidel (MEX)   MT53
# 49              Marathon      2019         Takeuchi, Ryoma (JPN)  25-29
#
#    City,State    05K    10K    15K    20K   HALF    25K    30K    35K    40K  \
# 0         335  10:52  10:46  11:02  11:32  02:37  09:13  10:46  10:57  10:54
# 1           4  14:45  14:43  14:43  14:50  03:14  11:42  15:02  14:55  15:16
# 2         201  11:03  10:34  10:52  11:13  02:13  08:15  10:12  10:39  10:45
# 3         340  10:51  10:46  11:03  11:32  02:37  09:12  10:47  11:13  11:08
# 4          38  14:45  14:44  14:43  14:50  03:14  11:40  15:03  14:54  15:15
# 5         218  11:03  10:35  10:50  11:14  02:17  08:27  10:52  11:40  11:39
# 6         334  11:40  12:14  10:33  12:17  02:52  10:04  11:53  12:26  12:22
# 7           5  14:46  14:43  14:43  14:50  03:13  11:40  15:04  14:54  15:15
# 8         202  11:03  10:37  10:50  11:13  02:21  08:24  10:51  11:40  11:39
# 9         338  13:10  12:16  13:02  13:25  03:01  10:45  12:25  13:27  14:03
# 10          9  14:45  14:42  14:43  14:52  03:13  11:39  15:05  14:54  15:16
# 11        221  11:04  10:36  10:49  11:14  02:18  08:27  10:50  11:40  11:39
# 12        332  12:48  12:21  12:58  14:24  03:14  11:08  13:28  14:53  13:48
# 13         10  14:47  14:43  14:53  15:09  03:22  11:59  15:29  14:53  14:38
# 14        214  11:04  10:37  10:49  11:13  02:22  08:22  10:52  11:39  11:40
# 15        333  12:56  12:59  13:54  14:30  03:04  11:19  14:19  14:09  14:33
# 16         39  14:46  14:43  14:43  14:50  03:13  11:41  15:03  14:54  16:20
# 17        206  11:04  10:34  10:51  11:13  02:17  08:27  10:52  11:41  11:38
# 18        331  14:32  15:05  15:04  15:05  01:48  12:36  15:16  14:47  15:37
# 19          6  14:45  14:42  14:44  14:50  03:13  11:41  15:03  15:29  16:38
# 20        209  11:04  10:38  10:49  11:12  02:18  08:25  10:53  11:40  11:39
# 21        337  17:20  16:49  17:38  17:51  03:48  15:47  23:22  20:11  24:22
# 22          1  14:47  14:42  14:54  15:09  03:22  12:00  15:36  15:53  16:05
# 23        205  11:04  10:36  10:51  11:12  02:16  08:28  10:52  11:41  11:38
# 24        336  19:53  21:00  22:15  22:44  05:26  20:50  23:29  24:40  22:12
# 25         16  15:33  15:26  15:31  15:29  03:25  12:09  15:44  15:27  15:18
# 26        204  11:03  10:34  10:53  11:12  02:16  08:27  10:55  11:39  11:39
# 27         36  15:33  15:25  15:32  15:29  03:26  12:07  15:45  15:27  15:18
# 28        211  11:02  10:40  10:46  11:14  02:23  08:41  11:01  11:22  11:29
# 29         23  15:32  15:26  15:32  15:29  03:26  12:07  15:45  15:27  15:19
# 30        217  11:03  10:41  10:46  11:12  02:19  08:43  11:03  11:20  11:30
# 31         20  15:32  15:26  15:31  15:30  03:26  12:08  15:46  15:29  15:15
# 32        210  11:04  10:38  10:47  11:13  02:21  08:42  11:01  11:21  11:32
# 33         11  15:25  15:34  15:30  15:30  03:25  12:10  15:45  15:26  15:30
# 34        213  11:03  10:39  10:48  11:11  02:23  08:40  11:03  11:21  11:31
# 35         21  15:34  15:26  15:31  15:30  03:24  12:08  15:45  15:27  15:24
# 36        220  11:03  10:41  10:46  11:13  02:23  08:56  11:36  12:36  12:12
# 37         15  15:33  15:26  15:30  15:29  03:27  12:07  15:45  15:29  15:27
# 38        208  11:05  10:38  10:48  11:11  02:24  08:56  11:36  12:37  12:11
# 39         17  15:33  15:25  15:33  15:28  03:26  12:09  15:44  15:37  15:45
# 40        207  11:05  10:38  10:48  11:33  02:32  09:27  11:30  12:05  11:55
# 41         25  15:32  15:27  15:31  15:30  03:25  12:09  15:44  15:36  15:50
# 42        212  11:04  10:37  10:51  11:12  02:24  09:56  12:03  12:31  12:28
# 43         24  15:33  15:26  15:32  15:30  03:25  12:08  15:45  15:36  15:45
# 44        216  11:05  10:39  10:47  12:58  02:55  10:06  11:58  12:40  12:33
# 45         19  15:34  15:26  15:31  15:30  03:25  12:09  15:43  15:37  15:51
# 46        226  11:05  10:38  10:48  11:46  02:56  11:17  11:57  12:41  12:34
# 47         14  15:26  15:32  15:32  15:29  03:26  12:08  15:45  15:37  15:57
# 48        219  11:04  10:39  10:49  12:30  03:06  10:23  11:57  12:40  12:34
# 49         12  15:33  15:26  15:31  15:29  03:26  12:09  15:45  15:38  16:22
#
#    Finish
# 0   04:51
# 1   06:35
# 2   04:40
# 3   05:23
# 4   06:38
# 5   04:54
# 6   06:15
# 7   06:40
# 8   04:54
# 9   07:11
# 10  06:44
# 11  04:55
# 12  06:46
# 13  06:21
# 14  04:55
# 15  06:53
# 16  08:22
# 17  04:57
# 18  06:51
# 19  08:06
# 20  04:56
# 21  12:26
# 22  07:30
# 23  04:56
# 24  11:58
# 25  06:34
# 26  05:01
# 27  06:35
# 28  05:02
# 29  06:50
# 30  05:08
# 31  06:53
# 32  05:12
# 33  06:47
# 34  05:15
# 35  07:01
# 36  05:31
# 37  07:01
# 38  05:31
# 39  06:58
# 40  05:30
# 41  06:58
# 42  05:31
# 43  07:04
# 44  05:29
# 45  07:08
# 46  05:30
# 47  07:33
# 48  05:36
# 49  07:07
