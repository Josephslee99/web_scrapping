# %% [markdown]
# # Project 4: Scrapping marathon results
# #### Seungmin Lee || 50230433
# ---
# ## Objective
# ---
# Our goal for this project is to retrieve data from the [2019 Chicago Marathon](https://results.chicagomarathon.com/well-known/2019/) and create a dataframe showing the top 50 male runners.
#
# For that purpose we will be using the follow tools:
# - `requests`: Allows us to retrieve data from a website.
# - `BeautifulSoup`: Aides in sorting html information.
# - `pandas`: Will be used in creating a data frame containing top 50 male runners.
# - `time`: Adds a delay for get requests to prevent potential issues.

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import time

# %%
# Specific parameters to obtain top 50 male contenders
params = {"event":"MAR", "search[sex]":"M", "search[age_class]":"%", "num_results":"50"}
marathonURL = requests.get("https://results.chicagomarathon.com/well-known/2019/?pid=list", params = params).text
soup = BS(marathonURL)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Bank of America Chicago Marathon
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="//results-static.mikatiming.com/2019/chicago/../../stages/blue/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="198023663696085" property="fb:app_id"/>
#   <meta content="https://results-static.mikatiming.com/2019/chicago/styles/responsive_2016/logo_fb.png" property="og:image"/>
#   <meta content="630" property="og:image:width"/>
#   <meta content="315" property="og:image:height"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Mika timing" property="og:site_name"/>
#   <meta content="https://results.chicagomarathon.com/2019/?content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25" property="og:url"/>
#   <meta content="Bank of America Chicago Marathon: Results" property="og:title"/>
#   <link href="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/css/bootstrap.css" rel="stylesheet"/>
#   <link href="//results-static.mikatiming.com/stages/blue/lib/static/styles.build/responsive_2016/style.css" rel="stylesheet"/>
#   <link href="/2019/?content=css_event&amp;theme=responsive&amp;event=2019_chicago&amp;style=responsive_2016" rel="stylesheet" type="text/css"/>
#   <link href="//results-static.mikatiming.com/stages/blue/images/favicon.ico" rel="shortcut icon"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/bootstrap-3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="/2019/?content=ajax2&amp;client=js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var require = {"baseUrl":"\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static","deps":["\/\/results-static.mikatiming.com\/stages\/blue\/lib\/static\/webcomponentsjs-0.7.0\/webcomponents-lite.js"],"paths":{"d3":"d3-3.4.13\/d3","c3":"c3-0.4.8\/c3","moment":"moment.js-2.9.0\/moment-with-locales.min","GDouglasPeuker":"GDouglasPeuker","Mika":"Mika.build","async":"require.js-plugins-1.0.3\/async","combokeys":"combokeys-2.3.0\/dist\/combokeys","videojs":"video.js-5.10.8\/dist\/video","hls":"videojs-contrib-hls","hls2":"videojs5-hlsjs-source-handler\/dist\/videojs5-hlsjs-source-handler","nouislider":"noUiSlider-9.2.0\/nouislider.min","screenfull":"screenfull.js-4.0.0\/screenfull","lodashIsEqual":"lodash\/isEqual","Mika\/Dialog":"Mika.build\/Dialog.js?cf670e2cc8","Mika\/Environment":"Mika.build\/Environment.js?f6fa671d7e","Mika\/FavoriteColorMapper":"Mika.build\/FavoriteColorMapper.js?23e7b1bdb2","Mika\/ImageErrorHandler":"Mika.build\/ImageErrorHandler.js?bb68fb34c5","Mika\/ImageViewer":"Mika.build\/ImageViewer.js?4c415f5b45","Mika\/Logger":"Mika.build\/Logger.js?e2c0b9813c","Mika\/Map\/FavoriteBar":"Mika.build\/Map\/FavoriteBar.js?8b9ba8ee82","Mika\/Map\/LatLng":"Mika.build\/Map\/LatLng.js?0152bb4684","Mika\/Map\/LatLngBounds":"Mika.build\/Map\/LatLngBounds.js?3949b2375b","Mika\/Map\/Map":"Mika.build\/Map\/Map.js?4214ae1dcf","Mika\/Map\/Marker\/Cluster\/Cluster":"Mika.build\/Map\/Marker\/Cluster\/Cluster.js?7ba650ad59","Mika\/Map\/Marker\/Cluster\/Icon":"Mika.build\/Map\/Marker\/Cluster\/Icon.js?1753d81d7d","Mika\/Map\/Marker\/Cluster\/MarkerCluster":"Mika.build\/Map\/Marker\/Cluster\/MarkerCluster.js?dc3240a662","Mika\/Map\/Marker\/CollisionSupressor":"Mika.build\/Map\/Marker\/CollisionSupressor.js?bf7b4e718e","Mika\/Map\/Marker\/CustomImage":"Mika.build\/Map\/Marker\/CustomImage.js?36e9b6e86b","Mika\/Map\/Marker\/Flag":"Mika.build\/Map\/Marker\/Flag.js?b307c0e6ea","Mika\/Map\/Marker\/Icons":"Mika.build\/Map\/Marker\/Icons.js?7ed480f156","Mika\/Map\/Marker\/Km":"Mika.build\/Map\/Marker\/Km.js?bf628dac4c","Mika\/Map\/Marker\/Overlay":"Mika.build\/Map\/Marker\/Overlay.js?168056281d","Mika\/Map\/Marker\/OverlayImage":"Mika.build\/Map\/Marker\/OverlayImage.js?11cc140f44","Mika\/Map\/Marker\/Person":"Mika.build\/Map\/Marker\/Person.js?f2122d3356","Mika\/Map\/Object\/Circle":"Mika.build\/Map\/Object\/Circle.js?ca85414603","Mika\/Map\/Polyline":"Mika.build\/Map\/Polyline.js?d79227cd81","Mika\/Mika":"Mika.build\/Mika.js?d1a053dda5","Mika\/PolylineEditor":"Mika.build\/PolylineEditor.js?4f28561b02","Mika\/Popover":"Mika.build\/Popover.js?12f2df5658","Mika\/Quicksearch":"Mika.build\/Quicksearch.js?1be7035fa7","Mika\/Results\/Board":"Mika.build\/Results\/Board.js?7eac7a5764","Mika\/Results\/Plugins\/favorite_display":"Mika.build\/Results\/Plugins\/favorite_display.js?a3da44b3af","Mika\/Results\/Plugins\/favorites":"Mika.build\/Results\/Plugins\/favorites.js?992edb5b12","Mika\/Results\/Plugins\/global_option_bar":"Mika.build\/Results\/Plugins\/global_option_bar.js?55da35bc04","Mika\/Results\/Plugins\/graph":"Mika.build\/Results\/Plugins\/graph.js?5d3cfdc1ef","Mika\/Results\/Plugins\/list":"Mika.build\/Results\/Plugins\/list.js?c55c8547df","Mika\/Results\/Plugins\/list_responsive":"Mika.build\/Results\/Plugins\/list_responsive.js?c8c734b26e","Mika\/Results\/Plugins\/main_buttons":"Mika.build\/Results\/Plugins\/main_buttons.js?97fc6ff08c","Mika\/Results\/Plugins\/map":"Mika.build\/Results\/Plugins\/map.js?f2476a2270","Mika\/Results\/Plugins\/overlays":"Mika.build\/Results\/Plugins\/overlays.js?581537610c","Mika\/Results\/Plugins\/pacegraph":"Mika.build\/Results\/Plugins\/pacegraph.js?6a9b1e0995","Mika\/Results\/Plugins\/race_flow_table":"Mika.build\/Results\/Plugins\/race_flow_table.js?e17b8229d1","Mika\/Results\/Plugins\/remote_content":"Mika.build\/Results\/Plugins\/remote_content.js?0a5e77255e","Mika\/Results\/Plugins\/strings":"Mika.build\/Results\/Plugins\/strings.js?fe0a2db490","Mika\/Results\/Requester":"Mika.build\/Results\/Req ...
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/require.js-2.3.6/require.min.js" type="text/javascript">
#   </script>
#   <script src="//results-static.mikatiming.com/stages/blue/lib/static/Emitter.js" type="text/javascript">
#   </script>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <script type="text/javascript">
#    // create helper function to handle the image loading errors
#         var mikaImageErrorHandler = function (image) {
#             require(["Mika/ImageErrorHandler"], function (ImageErrorHandler) {
#                 var que = ImageErrorHandler.queueImageGeneration(image.dataset.generateSrcUrl, image.dataset.imageHash, image.src);
#                 setTimeout(function () {
#                      ImageErrorHandler.statusMissingImages(que);
#                 }, 1100);
#             })
#         };
#         require(["Mika/Mika", "require"], function (Mika, require) {
#             new Mika();
#             require(["Mika/Dialog", "Mika/Popover", "Mika/ImageViewer", "Mika/Timer"]);
#         });
#   </script>
#  </head>
#  <body class="pid-list content-list view-public branch-production site-2019_chicago event-MAR">
#   <header class="hidden-xs">
#    <div class="container">
#     <div class="logo row">
#      <a href="/2019/?lang=EN_CAP">
#       <img alt="" class="logo-screen" src="//results-static.mikatiming.com/2019/chicago/../chicago/styles/responsive_2016/logo.png"/>
#      </a>
#      <ul class="header-brand">
#       <li>
#        Race Results
#       </li>
#       <li>
#        Unofficial Race Results
#       </li>
#       <li>
#        Start Time: 07:30:02.213
#       </li>
#      </ul>
#     </div>
#    </div>
#   </header>
#   <nav class="navbar navbar-default navbar-top navbar-fixed-top">
#    <div class="container">
#     <div class="navbar-header">
#      <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="/2019/?lang=EN_CAP">
#       <img alt="" class="hidden-sm hidden-md hidden-lg" src="//results-static.mikatiming.com/2019/chicago/../chicago/styles/responsive_2016/logo.png"/>
#       <span class="hidden-xs">
#        Bank of America Chicago Marathon 2019
#       </span>
#      </a>
#     </div>
#     <div class="navbar-collapse collapse" id="navbar">
#      <ul class="nav navbar-nav hidden-sm hidden-md hidden-lg">
#       <li class="active">
#        <a class="nav-pid-start" href="/2019/?event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=start&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#         <span>
#          Results
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-leaderboard" href="/2019/?lang=EN_CAP&amp;pid=leaderboard">
#         <span>
#          Leaderboard
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-leaderboard_sprint" href="/2019/?lang=EN_CAP&amp;pid=leaderboard_sprint">
#         <span>
#          Bonus Competition
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-tracking" href="/2019/?lang=EN_CAP&amp;pid=tracking">
#         <span>
#          Tracking
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="nav-pid-favorites" href="/2019/?lang=EN_CAP&amp;pid=favorites">
#         <span>
#          My Runners
#         </span>
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li class="">
#        <a class="" href="https://chicago-history.r.mikatiming.com/" role="button">
#         to Results 1996-2018
#        </a>
#       </li>
#       <li class="">
#        <a class="" href="http://www.chicagomarathon.com/" role="button">
#         Back to Homepage
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </nav>
#   <!-- header end -->
#   <!-- main start -->
#   <script type="text/javascript">
#    //<![CDATA[
# var _gaq=_gaq||[];var ga_track={};ga_track.trackersArray=new Array();ga_track.push=function(){var arr=[],ta=ga_track.trackersArray;arr.push.apply(arr,arguments);for(var t=ta.length-1;t>-1;--t){for(var i=arr.length-1;i>-1;--i){var _pos=arr[i][0].indexOf('_');arr[i][0]=(_pos<1)?(ta[t]+arr[i][0]):(ta[t]+arr[i][0].substr(_pos));_gaq.push(arr[i]);}}};
# _gaq.push(['_gat._anonymizeIp']);
# _gaq.push(['t0._setAccount', 'UA-8939914-17']);
# _gaq.push(['t0._setCustomVar', 1, 'Event', 'MAR']);
# _gaq.push(['t0._trackPageview', '/2019_chicago' + window.location.pathname + window.location.search + window.location.hash]);
# ga_track.trackersArray.push('t0.');
# _gaq.push(['t1._setAccount', 'UA-8939914-1']);
# _gaq.push(['t1._setCustomVar', 1, 'Event', 'MAR']);
# _gaq.push(['t1._trackPageview', '/2019_chicago' + window.location.pathname + window.location.search + window.location.hash]);
# ga_track.trackersArray.push('t1.');
#
#         (function () {
#             var ga = document.createElement('script');
#             ga.type = 'text/javascript';
#             ga.async = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(ga, s);
#         })();
#
#         //]]>
#   </script>
#   <section class="section-nav container-fluid">
#    <nav class="navbar navbar-default row navbar-main hidden-xs">
#     <div class="container">
#      <ul class="nav navbar-nav">
#       <li class="active nav-pid-start">
#        <a href="/2019/?lang=EN_CAP&amp;pid=start&amp;pidp=start">
#         <span>
#          Results
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-leaderboard">
#        <a href="/2019/?lang=EN_CAP&amp;pid=leaderboard&amp;pidp=leaderboard">
#         <span>
#          Leaderboard
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-leaderboard_sprint">
#        <a href="/2019/?lang=EN_CAP&amp;pid=leaderboard_sprint&amp;pidp=leaderboard_sprint">
#         <span>
#          Bonus Competition
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-tracking">
#        <a href="/2019/?lang=EN_CAP&amp;pid=tracking&amp;pidp=tracking">
#         <span>
#          Tracking
#         </span>
#        </a>
#       </li>
#       <li class="nav-pid-favorites">
#        <a href="/2019/?lang=EN_CAP&amp;pid=favorites&amp;pidp=favorites">
#         <span>
#          My Runners
#         </span>
#        </a>
#       </li>
#       <li class="dropdown hide">
#        <a aria-expanded="true" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="javascript:void(0);" id="navbar-main-dropdown">
#         More
#         <span class="caret">
#         </span>
#        </a>
#        <ul aria-labelledby="navbar-main-dropdown" class="dropdown-menu">
#        </ul>
#       </li>
#       <script type="text/javascript">
#        jQuery("#navbar-main-dropdown").dropdown();
#                 var menuResizeHandler = function () {
#                     var container   = jQuery(".navbar-main .container");
#                     var navbar   = jQuery(".navbar-main .nav");
#                     var currentWidth = 0;
#                     var dropdown = navbar.find("li.dropdown");
#                     // quickly show it and get the width
#                     dropdown.removeClass("hide");
#                     var dropdownWidth = dropdown.width();
#                     var quicksearchWidth = jQuery(".navbar-main .quicksearch-form").width();
#                     currentWidth += quicksearchWidth;
#                     var menuEntries = navbar.find("li:not(.dropdown)");
#                     menuEntries.each(function (i) {
#                         navbar.append(this);
#                     });
#                     navbar.append(dropdown);
#                     dropdown.addClass("hide").removeClass("active");
#
#                     var maxWidth = container.width();
#                     menuEntries.each(function (i) {
#                         currentWidth += jQuery(this).width();
#
#                         var next = false;
#                         if (typeof menuEntries[i+1] !== "undefined") {
#                             next = menuEntries[i+1];
#                         }
#                         var currentIsAboveMaxWidth = (currentWidth > maxWidth);
#                         var currentIsNotLastAndPlusDropdownIsAboveMaxWidth = ((currentWidth + dropdownWidth > maxWidth) && i != menuEntries.length-1);
#                         var currentPlusNextIsAboveMaxWidth = (next && currentWidth + jQuery(next).width() > maxWidth);
#                         //console.log("%s: width: %s, is above: %s, notlast: %s, plusnext: %s", jQuery(this).text(), currentWidth, currentIsAboveMaxWidth, currentIsNotLastAndPlusDropdownIsAboveMaxWidth, currentPlusNextIsAboveMaxWidth)
#                         if(currentIsAboveMaxWidth || currentIsNotLastAndPlusDropdownIsAboveMaxWidth || currentPlusNextIsAboveMaxWidth) {
#                             jQuery(this).find("a").popover("destroy");
#                             dropdown.find("ul").append(this);
#                             dropdown.removeClass("hide");
#                             if (jQuery(this).hasClass("active")) {
#                                 dropdown.addClass("active");
#                             }
#                         }
#                     });
#
#                 };
#                 jQuery(document).on("ready", menuResizeHandler);
#                 var lastWidth = 0;
#                 jQuery(window).on("resize", function () {
#                     lastWidth = window.innerWidth;
#                     setTimeout(function () {
#                         if (lastWidth == window.innerWidth) {
#                             menuResizeHandler();
#                         }
#                     }, 100);
#                 });
#       </script>
#      </ul>
#     </div>
#    </nav>
#    <!-- menu end -->
#   </section>
#   <section class="section-main">
#    <div class="container" id="main-content">
#     <div class="row">
#      <div class="cbox-main pid-list col-xs-12" id="cbox-main">
#       <!-- cbox include start -->
#       <div class="row">
#        <div class="col-xs-10">
#         <h2>
#          Results: Marathon
#         </h2>
#        </div>
#       </div>
#       <ul class="row-xs list-group list-info">
#        <li class="list-group-item">
#         Unofficial Results |
#         <span class="sex">
#          Men
#         </span>
#        </li>
#       </ul>
#       <div class="col-sm-12 row-xs">
#        <ul class="list-group list-group-multicolumn">
#         <li class="list-group row list-group-item list-group-header">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs" style="width: 40px">
#             Place Overall
#            </div>
#            <div class="list-field type-place place-primary" style="width: 40px">
#             Place Gender
#            </div>
#            <div class="list-field type-fullname">
#             Name (CTZ)
#            </div>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 hidden-xs hidden-sm list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              BIB
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              Division
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              HALF
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              Finish
#             </div>
#             <div class="list-field type-favorite" style="width: 13px">
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             1
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             1
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A4AD&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Cherono, Lawrence (KEN)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              4
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:15
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:05:45
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A4AD">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             2
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             2
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A49E&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Debela, Dejene (ETH)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              38
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              20-24
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:16
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:05:46
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A49E">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             3
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             3
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A482&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Mengstu, Asefa (ETH)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              5
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:15
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:05:48
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A482">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             4
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             4
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A485&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Karoki, Bedan (KEN)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              9
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:15
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:05:53
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A485">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             5
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             5
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A486&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Abdi, Bashir (BEL)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              10
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:54
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:06:14
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A486">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             6
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             6
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A4B2&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Tura, Seifu (ETH)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              39
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              20-24
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:15
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:08:35
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A4B2">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             7
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             7
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A483&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Chumba, Dickson (KEN)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              6
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:14
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:09:11
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A483">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             8
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             8
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A481&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Farah, Mo (GBR)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              1
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              35-39
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:02:54
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:09:58
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A481">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             9
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             9
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A48B&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Riley, Jacob (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              16
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:05:24
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:10:36
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A48B">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             10
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             10
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A49C&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Mock, Jerrell (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              36
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              20-24
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:05:25
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:10:37
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A49C">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             11
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             11
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A4AF&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Stinson, Parker (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              23
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:05:25
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:10:53
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A4AF">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             12
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             12
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A48F&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Bumbalough, Andrew (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              20
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:05:25
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:10:56
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A48F">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             13
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             13
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A487&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Oishi, Minato (JPN)
#             </a>
#            </h4>
#           </div>
#          </div>
# ...
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             47
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             46
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA312000022AB8E&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Bang, Eric (CAN)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              370
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:08:22
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:19:56
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA312000022AB8E">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             48
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             47
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA317000023A497&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Eaton, Michael (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              29
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:09:02
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:19:58
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A497">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             49
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             48
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA312000022AC40&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Thomas, Jason (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              665
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:09:53
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:20:28
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA312000022AC40">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-active list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             50
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             49
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA312000022ACE2&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Nally, Daniel (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              580
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              30-34
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:09:53
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:20:38
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA312000022ACE2">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="list-group-item row">
#          <div class="col-xs-12 col-sm-12 col-md-5 list-field-wrap">
#           <div class="row">
#            <div class="list-field type-place place-secondary hidden-xs numeric" style="width: 40px">
#             53
#            </div>
#            <div class="list-field type-place place-primary numeric" style="width: 40px">
#             50
#            </div>
#            <h4 class="list-field type-fullname">
#             <a href="?content=detail&amp;fpid=list&amp;pid=list&amp;idp=999999107FA312000022AC68&amp;lang=EN_CAP&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;search_event=MAR">
#              Craighead, Daniel (USA)
#             </a>
#            </h4>
#           </div>
#          </div>
#          <div class="col-xs-12 col-sm-12 col-md-7 list-field-wrap">
#           <div class="pull-left">
#            <div class="row">
#             <div class="list-field type-field" style="width: 45px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               BIB
#              </div>
#              430
#             </div>
#             <div class="list-field type-age_class" style="width: 65px">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Division
#              </div>
#              25-29
#             </div>
#            </div>
#           </div>
#           <div class="pull-right">
#            <div class="row">
#             <div class="split list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               HALF
#              </div>
#              01:09:22
#             </div>
#             <div class="list-field type-time">
#              <div class="visible-xs-block visible-sm-block list-label">
#               Finish
#              </div>
#              02:21:15
#             </div>
#             <div class="list-field type-favorite text-right" style="width: 13px">
#              <a class="icon l" href="?content=well-known&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA312000022AC68">
#               <img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="row">
#        <div class="col-xs-8 col-sm-9 col-md-6">
#         <div aria-label="" class="btn-toolbar list-actions" role="toolbar">
#          <div class="btn-group" role="group">
#           <a class="btn btn-default" href="?pid=start&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#            Back / New Search
#           </a>
#           <a class="btn btn-default hidden-xs" href="?content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#            Reload
#           </a>
#           <a class="btn btn-default hidden-xs" href="#" onclick="open_print('?print=1&amp;content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25');">
#            Print
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-xs-4 col-sm-3 col-md-6">
#         <div class="pull-right pages">
#          <ul class="pagination">
#           <li class="hidden-xs hidden-sm active">
#            <a href="?page=1&amp;content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             1
#            </a>
#           </li>
#           <li class="hidden-xs hidden-sm">
#            <a href="?page=2&amp;content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             2
#            </a>
#           </li>
#           <li class="hidden-xs hidden-sm">
#            <a href="?page=3&amp;content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             3
#            </a>
#           </li>
#           <li class="disabled">
#            <a aria-label="" class="hidden-xs hidden-sm" href="#">
#             <span aria-hidden="true">
#              ...
#             </span>
#            </a>
#           </li>
#           <li class="hidden-xs hidden-sm">
#            <a href="?page=492&amp;content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             492
#            </a>
#           </li>
#           <li class="pages-nav-button">
#            <a href="?page=2&amp;content=well-known&amp;event=MAR&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25">
#             &gt;
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <!-- cbox include end -->
#      </div>
#     </div>
#     <!-- row -->
#    </div>
#    <!-- container main-content -->
#   </section>
#   <!-- section-main -->
#   <!-- main end -->
#   <!-- footer start -->
#   <footer>
#    <div class="container">
#     <div class="row">
#      <div class="footer-box legal-footer" id="pid-list">
#       <div class="col-xs-12">
#        <a class="pull-right" href="https://www.mikatiming.de/">
#         mika:timing GmbH © 2021
#        </a>
#        <a href="https://www.mikatiming.de/en/service/legal-notice/">
#         Legal Notice
#        </a>
#        |
#        <a href="https://www.mikatiming.de/en/service/legal-notice/privacy-policy/">
#         Privacy Policy
#        </a>
#       </div>
#      </div>
#     </div>
#     <!-- row end -->
#    </div>
#    <!-- container end -->
#   </footer>
#   <!-- footer section end -->
#   <div class="popup-info" id="popup-info" style="display:none;">
#   </div>
#   <div class="popup" id="popup" style="display:none;">
#   </div>
#  </body>
# </html>
# <!-- footer end -->

# %% [markdown]
# Since we will be pulling information for all 50 male runners, we need to know what type of information we will be working with. To start, we will be accessing the first place male runner, Cherono, Lawrence.

# %%
# URL linking to Lawrence's profile
test1 = requests.get("https://results.chicagomarathon.com/well-known/2019/?content=detail&fpid=list&pid=list&idp=999999107FA317000023A4AD&lang=EN_CAP&event=MAR&lang=EN_CAP&num_results=50&search%5Bsex%5D=M&search%5Bage_class%5D=%25&search_event=MAR").text
soup1 = BS(test1)
# Most of the data we will be working with is under the "td" tag
tdTag = soup1.find_all("td")
tdTag
# Out:
# [<td class="f-__fullname last">Cherono, Lawrence (KEN)</td>,
#  <td class="f-age_class last">30-34</td>,
#  <td class="f-start_no_text last">4</td>,
#  <td class="f-age last">31</td>,
#  <td class="f-__city_state last">Chepkoilel</td>,
#  <td class="f-display_name_short last">LC</td>,
#  <td class="f-starttime_net last">07:30:03</td>,
#  <td class="f-place_all last">1</td>,
#  <td class="f-place_age last">1</td>,
#  <td class="f-place_nosex last">1</td>,
#  <td class="f-time_finish_netto last">02:05:45</td>,
#  <td class="f-__nix last"><a class="icon l" href="?content=detail&amp;idp=999999107FA317000023A4AD&amp;lang=EN_CAP&amp;num_results=50&amp;pid=list&amp;search%5Bsex%5D=M&amp;search%5Bage_class%5D=%25&amp;event=MAR&amp;favorite_add=999999107FA317000023A4AD"><img alt="Add runner to 'My Runners'" src="//assets.mikatiming.com/img/mt/results/default/icons/add.svg" title="Add runner to 'My Runners'"/></a></td>,
#  <td class="time_day">07:44:48AM</td>,
#  <td class="time">00:14:45</td>,
#  <td class="diff">14:45</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">02:57</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">20.34</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:45</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.64</td>,
#  <td class="time_day">07:59:31AM</td>,
#  <td class="time">00:29:28</td>,
#  <td class="diff">14:43</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">02:57</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">20.39</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:45</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.67</td>,
#  <td class="time_day">08:14:13AM</td>,
#  <td class="time">00:44:11</td>,
#  <td class="diff">14:43</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">02:57</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">20.39</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:45</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.67</td>,
#  <td class="time_day">08:29:04AM</td>,
#  <td class="time">00:59:01</td>,
#  <td class="diff">14:51</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">02:59</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">20.22</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:47</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.57</td>,
#  <td class="time_day">08:32:17AM</td>,
#  <td class="time">01:02:15</td>,
#  <td class="diff">03:14</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">02:57</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">20.38</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:45</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.66</td>,
#  <td class="time_day">08:43:59AM</td>,
#  <td class="time">01:13:57</td>,
#  <td class="diff">11:42</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">03:00</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">20.03</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:50</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.45</td>,
#  <td class="time_day">08:59:01AM</td>,
#  <td class="time">01:28:59</td>,
#  <td class="diff">15:03</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">03:01</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">19.94</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:51</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.39</td>,
#  <td class="time_day">09:13:56AM</td>,
#  <td class="time">01:43:54</td>,
#  <td class="diff">14:55</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">02:59</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">20.13</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:48</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.51</td>,
#  <td class="time_day">09:29:12AM</td>,
#  <td class="time">01:59:10</td>,
#  <td class="diff">15:17</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">03:04</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">19.65</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:55</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.21</td>,
#  <td class="time_day">09:35:47AM</td>,
#  <td class="time">02:05:45</td>,
#  <td class="diff">06:36</td>,
#  <td class="min_km right opt colgroup-splits colgroup-splits-metric">03:01</td>,
#  <td class="kmh colgroup-splits colgroup-splits-metric">19.99</td>,
#  <td class="min_mile right opt colgroup-splits colgroup-splits-imperial">04:50</td>,
#  <td class="miles_h right opt colgroup-splits colgroup-splits-imperial last">12.43</td>,
#  <td class="last"><div class="row">
#  <div class="feature col-xs-12 col-sm-6"><span><a class="btn img" href="http://www.marathonfoto.com/In?RaceOID=12852019M1&amp;LastName=Cherono&amp;BibNumber=4" onclick="ga_track.push(['_trackPageview', '/2019_chicago/outgoing/MarathonFotoRaceDayPhotos']); ga_track.push(['_trackEvent', '2019_chicago_Features', 'Feature', 'MarathonFotoRaceDayPhotos']);" style="padding:0px;" target="_blank"><img alt="MarathonFoto Race Day Photos" class="img-responsive" src="//assets.mikatiming.com/img/mt/results/default/images/button_photo.svg" style="vertical-align:middle;" title="MarathonFoto Race Day Photos"/></a> <a class="btn btn-primary btn-block" href="http://www.marathonfoto.com/In?RaceOID=12852019M1&amp;LastName=Cherono&amp;BibNumber=4" onclick="ga_track.push(['_trackPageview', '/2019_chicago/outgoing/MarathonFotoRaceDayPhotos']); ga_track.push(['_trackEvent', '2019_chicago_Features', 'Feature', 'MarathonFotoRaceDayPhotos']);" target="_blank">MarathonFoto Race Day Photos</a></span></div></div></td>]

# %% [markdown]
# The information that we want are the following:
# - Name: `<td class="f-__fullname last">`
# - Age Group: `<td class="f-age_class last">`
# - bib Number: `<td class="f-start_no_text last">`
# - Age: `<td class="f-age last">`
# - City/State: `<td class="f-__city_state last">`
# - Split Times: `<td class="time">`
#
# The first 5 can be obtained by slicing for the first 5 instances of "td".
#
# For Split Times, they'll be divided to the following:
# - 05K: Element 13
# - 10K: Element 21
# - 15K: Element 27
# - 20K: Element 34
# - HALF: Element 41
# - 25K: Element 48
# - 30K: Element 55
# - 35K: Element 62
# - 40K: Element 69
# - Finish: Element 76

# %%
# Obtains name, age group, bib number, age, city/state
first5 = [x.get_text() for x in tdTag[0:5]]
first5
# Out:
# ['Cherono, Lawrence (KEN)', '30-34', '4', '31', 'Chepkoilel']

# %%
# Obtains split times
times = [x.get_text() for x in tdTag[13:77:7]]
times
# Out:
# ['00:14:45',
#  '00:29:28',
#  '00:44:11',
#  '00:59:01',
#  '01:02:15',
#  '01:13:57',
#  '01:28:59',
#  '01:43:54',
#  '01:59:10',
#  '02:05:45']

# %%
# Brings the 2 together into 1 list containing everything we want
info = first5 + times
info
# Out:
# ['Cherono, Lawrence (KEN)',
#  '30-34',
#  '4',
#  '31',
#  'Chepkoilel',
#  '00:14:45',
#  '00:29:28',
#  '00:44:11',
#  '00:59:01',
#  '01:02:15',
#  '01:13:57',
#  '01:28:59',
#  '01:43:54',
#  '01:59:10',
#  '02:05:45']

# %%
h4tags = soup.find_all("h4") # Each runner's information/profile links are separated by the common "h4" tag
marathonList = []
for h4 in h4tags:
    profileURL = "https://results.chicagomarathon.com/2019/" + h4.find('a')['href'] 
    temp = requests.get(profileURL) # Pulling runner's profile
    tempSoup = BS(temp.text)
    tdTag = tempSoup.find_all("td")
    tempList = [x.get_text() for x in tdTag[0:5]] + [x.get_text() for x in tdTag[13:77:7]]
    marathonList.append(tempList) # Appends a list containing a runner's information from their profile
    time.sleep(2) # Ensures that there is a delay between each get request
print(marathonList)
# Out:
flagstaff', '00:15:33', '00:30:59', '00:46:29', '01:01:58', '01:05:25', '01:17:32', '01:33:17', '01:48:46', '02:04:13', '02:11:14'], ['Gregg, Brendan (USA)', '30-34', '17', '30', 'Davis', '00:15:33', '00:30:58', '00:46:31', '01:01:59', '01:05:25', '01:17:34', '01:33:18', '01:48:55', '02:04:40', '02:11:38'], ['Droddy, Noah (USA)', '25-29', '25', '29', 'Boulder', '00:15:32', '00:30:59', '00:46:30', '01:02:00', '01:05:25', '01:17:34', '01:33:18', '01:48:54', '02:04:44', '02:11:42'], ['Given, Wilkerson (USA)', '25-29', '24', '28', 'Atlanta', '00:15:33', '00:30:59', '00:46:31', '01:02:01', '01:05:26', '01:17:34', '01:33:19', '01:48:55', '02:04:40', '02:11:44'], ['Estrada, Diego (USA)', '25-29', '19', '29', 'Flagstaff', '00:15:34', '00:31:00', '00:46:31', '01:02:01', '01:05:26', '01:17:35', '01:33:18', '01:48:55', '02:04:46', '02:11:54'], ['Hayakawa, Tsubasa (JPN)', '25-29', '14', '29', 'Tahara', '00:15:26', '00:30:58', '00:46:30', '01:01:59', '01:05:25', '01:17:33', '01:33:18', '01:48:55', '02:04:52', '02:12:25'], ['Takeuchi, Ryoma (JPN)', '25-29', '12', '27', 'Matsudo Chiba', '00:15:33', '00:30:59', '00:46:30', '01:01:59', '01:05:25', '01:17:34', '01:33:19', '01:48:57', '02:05:19', '02:12:26'], ['Shrader, Brian (USA)', '25-29', '18', '28', 'Brighton', '00:15:34', '00:31:08', '00:46:49', '01:02:28', '01:05:54', '01:18:19', '01:34:05', '01:50:04', '02:06:16', '02:13:27'], ['Monroe, Alex (USA)', '25-29', '34', '27', 'Longmont' ...

# %%
# "col" contains the header for the data frame
col = ["Name (CTZ)","Age Group","Bib Number","Age","City,State","05K","10K","15K","20K","HALF","25K","30K","35K","40K","Finish"]
df = pd.DataFrame(marathonList, columns = col)
df
# Out:
#                      Name (CTZ) Age Group Bib Number Age     City,State  \
# 0       Cherono, Lawrence (KEN)     30-34          4  31     Chepkoilel
# 1          Debela, Dejene (ETH)     20-24         38  24   West Chester
# 2          Mengstu, Asefa (ETH)     30-34          5  31    Addis Ababa
# 3           Karoki, Bedan (KEN)     25-29          9  29          Mbuyu
# 4            Abdi, Bashir (BEL)     30-34         10  30       Nijmegen
# 5             Tura, Seifu (ETH)     20-24         39  22    Addis Abeba
# 6         Chumba, Dickson (KEN)     30-34          6  32      Kipngoror
# 7               Farah, Mo (GBR)     35-39          1  36     Teddington
# 8            Riley, Jacob (USA)     30-34         16  30        Boulder
# 9           Mock, Jerrell (USA)     20-24         36  24   Fort Collins
# 10        Stinson, Parker (USA)     25-29         23  27        Boulder
# 11     Bumbalough, Andrew (USA)     30-34         20  32        Concord
# 12          Oishi, Minato (JPN)     30-34         11  31      Hamamatsu
# 13      Mcdonald, Matthew (USA)     25-29         21  26        Atlanta
# 14           Smith, Scott (USA)     20-24         15  23      Flagstaff
